# %%
# !git clone https://github.com/beanmah/EGSteal.git
# %cd EGSteal
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'EGSteal' already exists and is not an empty directory.
# /content/EGSteal
# ...

# %%
import os

dataset_root = "dataset/NCI1"
os.makedirs(dataset_root, exist_ok=True)

print("Directory tree under /dataset:")
# !tree dataset || ls dataset
# Out:
# Directory tree under /dataset:
# /bin/bash: line 1: tree: command not found
# NCI1

# %%
# !python data_preparation.py --dataset_name NCI1
# Out:
# ...
# Traceback (most recent call last):
#   File "/content/EGSteal/data_preparation.py", line 150, in <module>
#     prepare_data(
#   File "/content/EGSteal/data_preparation.py", line 48, in prepare_data
#     temp_dataset = TUDataset(root=root, name=dataset_name)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch_geometric/datasets/tu_dataset.py", line 129, in __init__
#     super().__init__(root, transform, pre_transform, pre_filter,
#   File "/usr/local/lib/python3.12/dist-packages/torch_geometric/data/in_memory_dataset.py", line 81, in __init__
#     super().__init__(root, transform, pre_transform, pre_filter, log,
#   File "/usr/local/lib/python3.12/dist-packages/torch_geometric/data/dataset.py", line 112, in __init__
#     self._download()
#   File "/usr/local/lib/python3.12/dist-packages/torch_geometric/data/dataset.py", line 229, in _download
#     self.download()
# ...

# %%
import os

expected_files = [
    "processed_splits/queried_dataset_shadow.pt",
    "processed_splits/queried_dataset_train.pt"
]

for f in expected_files:
    path = os.path.join("dataset/NCI1", f)
    print(f"{f}: {'Found' if os.path.exists(path) else 'Missing'}")
# Out:
# processed_splits/queried_dataset_shadow.pt: Missing
# processed_splits/queried_dataset_train.pt: Missing

# %%
# !python target_model_inference.py --dataset_name NCI1 --explanation_mode CAM
# Out:
# /content/EGSteal/target_model_inference.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   info = torch.load(osp.join(save_dir, 'dataset_info.pt'))
# ...

# %%
# !zip -r week2_output.zip dataset results
# Out:
# 	zip warning: name not matched: results
#   adding: dataset/ (stored 0%)
#   adding: dataset/NCI1/ (stored 0%)
#   adding: dataset/NCI1/processed_splits/ (stored 0%)
#   adding: dataset/NCI1/raw/ (stored 0%)
#   adding: dataset/NCI1/raw/NCI1/ (stored 0%)
#   adding: dataset/NCI1/raw/NCI1/NCI1_A.txt (deflated 76%)
#   adding: dataset/NCI1/raw/NCI1/NCI1_graph_labels.txt (deflated 100%)
#   adding: dataset/NCI1/raw/NCI1/NCI1_node_labels.txt (deflated 94%)
#   adding: dataset/NCI1/raw/NCI1/README.txt (deflated 54%)
#   adding: dataset/NCI1/raw/NCI1/NCI1_graph_indicator.txt (deflated 98%)

# %%
from google.colab import files
files.download("week2_output.zip")
