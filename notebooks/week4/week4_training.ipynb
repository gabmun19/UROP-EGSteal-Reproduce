# %%
# !pip uninstall -y torch torch-geometric torch-scatter torch-sparse torch-cluster torchvision torchaudio
# !pip install torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0
# !pip install torch-geometric==2.4.0 torch-scatter==2.1.1 torch-sparse==0.6.18 torch-cluster==1.6.3 tqdm scikit-learn
# Out:
# Found existing installation: torch 2.8.0+cu126
# Uninstalling torch-2.8.0+cu126:
#   Successfully uninstalled torch-2.8.0+cu126
# WARNING: Skipping torch-geometric as it is not installed.
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# WARNING: Skipping torch-cluster as it is not installed.
# Found existing installation: torchvision 0.23.0+cu126
# Uninstalling torchvision-0.23.0+cu126:
#   Successfully uninstalled torchvision-0.23.0+cu126
# Found existing installation: torchaudio 2.8.0+cu126
# Uninstalling torchaudio-2.8.0+cu126:
#   Successfully uninstalled torchaudio-2.8.0+cu126
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.4/755.4 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.5 MB/s eta 0:00:00
# ...

# %%
# !pip install numpy==1.26.4 --force-reinstall
import numpy as np
print("NumPy version:", np.__version__)
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !git clone https://github.com/beanmah/EGSteal.git
# %cd EGSteal
# Out:
# fatal: destination path 'EGSteal' already exists and is not an empty directory.
# /content/EGSteal

# %%
# !mkdir -p dataset/NCI1/raw

# %%
# !wget -q https://www.chrsmrrs.com/graphkerneldatasets/NCI1.zip -O dataset/NCI1/raw/NCI1.zip
# !unzip -o dataset/NCI1/raw/NCI1.zip -d dataset/NCI1/raw/
# Out:
# Archive:  dataset/NCI1/raw/NCI1.zip
#    creating: dataset/NCI1/raw/NCI1/
#   inflating: dataset/NCI1/raw/NCI1/NCI1_node_labels.txt
#   inflating: dataset/NCI1/raw/NCI1/NCI1_A.txt
#   inflating: dataset/NCI1/raw/NCI1/README.txt
#   inflating: dataset/NCI1/raw/NCI1/NCI1_graph_indicator.txt
#   inflating: dataset/NCI1/raw/NCI1/NCI1_graph_labels.txt

# %%
# !ls -R dataset/NCI1/raw
# Out:
# dataset/NCI1/raw:
# NCI1	    NCI1_graph_indicator.txt  NCI1_node_labels.txt  README.txt
# NCI1_A.txt  NCI1_graph_labels.txt     NCI1.zip
#
# dataset/NCI1/raw/NCI1:
# NCI1_A.txt		  NCI1_graph_labels.txt  README.txt
# NCI1_graph_indicator.txt  NCI1_node_labels.txt

# %%
# !mv dataset/NCI1/raw/NCI1/* dataset/NCI1/raw/ 2>/dev/null
# !rm -r dataset/NCI1/raw/NCI1 2>/dev/null

# %%
# !ls dataset/NCI1/raw
# Out:
# NCI1_A.txt		  NCI1_graph_labels.txt  NCI1.zip
# NCI1_graph_indicator.txt  NCI1_node_labels.txt	 README.txt

# %%
# !python data_preparation.py --dataset_name NCI1
# Out:
# Processing...
# Done!
#
# Total number of graphs in NCI1: 4110
# Node features dimension: 37
# Edge features dimension: 0
# Number of classes: 2
#
# Dataset split sizes:
# Target train set size: 1315 (32.0%)
# Target val set size: 329 (8.0%)
# Test set size: 822 (20.0%)
# Shadow dataset size: 1644 (40.0%)
#
# Datasets saved in dataset/NCI1/processed_splits
# Saved files:
# - dataset_info.pt
# - target_train_dataset.pt
# - target_val_dataset.pt
# - test_dataset.pt
# - shadow_dataset.pt

# %%
# !python train_target_model.py \
    --dataset_name NCI1 \
    --gnn_backbone GIN \
    --gnn_layer 3 \
    --gnn_hidden_dim 128 \
    --epochs 200
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Number of node features: 37
# Number of classes: 2
# Target training dataset size: 1315
# Target validation dataset size: 329
# Test dataset size: 822
# Epochs: 100% 200/200 [03:34<00:00,  1.07s/it, Train Loss=0.0475, Train Acc=0.9817, Train AUC=0.9989, Val Loss=1.3471, Val Acc=0.7629, Val AUC=0.8184]
#
# Best Target GNN model saved to model_weights/NCI1/target_gnn_model.pth with Val AUC: 0.8307
# Test Accuracy of the best model: 0.7506
# Test AUC of the best model: 0.8147
# Best test accuracy and AUC saved to model_weights/NCI1/target_results.pt

# %%
# !python target_model_inference.py --dataset_name NCI1 --explanation_mode CAM
# Out:
# Loaded Target GNN model.
#
# Processing shadow_dataset.pt...
# Dataset Size: 1644
# /usr/local/lib/python3.12/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Processed 1024/1644 graphs.
# Processed 1644/1644 graphs.
# Saved processed dataset to dataset/NCI1/processed_splits/queried_dataset_shadow.pt
#
# Processing test_dataset.pt...
# Dataset Size: 822
# Processed 822/822 graphs.
# Saved processed dataset to dataset/NCI1/processed_splits/queried_dataset_test.pt

# %%
# !cp dataset/NCI1/processed_splits/queried_dataset_shadow.pt \
    dataset/NCI1/processed_splits/queried_dataset_train.pt

# %%
# !cp dataset/NCI1/processed_splits/queried_dataset_shadow.pt \
    dataset/NCI1/processed_splits/queried_dataset_val.pt

# !cp dataset/NCI1/processed_splits/queried_dataset_shadow.pt \
    dataset/NCI1/processed_splits/queried_dataset_train.pt

# %%
# !python train_surrogate_model.py \
    --dataset_name NCI1 \
    --gnn_backbone GIN \
    --gnn_layer 3 \
    --gnn_hidden_dim 128 \
    --epochs 200 \
    --augmentation_ratio 0.2 \
    --operation_ratio 0.2 \
    --align_weight 0.1 \
    --augmentation_type combined
# Out:
# Train Dataset Size: 1644
# Val Dataset Size: 1644
# Test Dataset Size: 822
# Starting training...
# Training: 100% 200/200 [12:03<00:00,  3.62s/it, Train Pred Loss=0.0474, Train RankNet Loss=0.4403, Val Acc=0.9884, Val AUC=0.9998]
#
# Best Validation AUC: 1.0000
# Test Accuracy: 0.7494
# Test AUC: 0.8094
# Fidelity Score: 0.8674
# Order Accuracy: 0.6660
# Rank Correlation: 0.3147
# Results saved to model_weights/NCI1/surrogate_results.pt

# %%
# !zip -r Week4Results.zip \
    model_weights \
    dataset/NCI1/processed_splits \
    -x "*.ipynb_checkpoints*" "*.DS_Store"
# Out:
#   adding: model_weights/ (stored 0%)
#   adding: model_weights/NCI1/ (stored 0%)
#   adding: model_weights/NCI1/target_results.pt (deflated 55%)
#   adding: model_weights/NCI1/target_gnn_model.pth (deflated 9%)
#   adding: model_weights/NCI1/surrogate_results.pt (deflated 51%)
#   adding: dataset/NCI1/processed_splits/ (stored 0%)
#   adding: dataset/NCI1/processed_splits/queried_dataset_shadow.pt (deflated 93%)
#   adding: dataset/NCI1/processed_splits/shadow_dataset.pt (deflated 98%)
#   adding: dataset/NCI1/processed_splits/test_dataset.pt (deflated 98%)
#   adding: dataset/NCI1/processed_splits/target_val_dataset.pt (deflated 98%)
#   adding: dataset/NCI1/processed_splits/target_train_dataset.pt (deflated 98%)
#   adding: dataset/NCI1/processed_splits/queried_dataset_train.pt (deflated 93%)
#   adding: dataset/NCI1/processed_splits/queried_dataset_test.pt (deflated 93%)
#   adding: dataset/NCI1/processed_splits/queried_dataset_val.pt (deflated 93%)
# ...

# %%
from google.colab import files
files.download("Week4Results.zip")
