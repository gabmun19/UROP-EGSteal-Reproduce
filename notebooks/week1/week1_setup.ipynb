# %%
# !git clone https://github.com/beanmah/EGSteal.git
# Out:
# fatal: destination path 'EGSteal' already exists and is not an empty directory.

# %%
# %cd EGSteal
# Out:
# /content/EGSteal

# %%
# !pip install -r requirements.txt

# %%
# !git clone https://github.com/DSE-MSU/EGSteal.git
# %cd EGSteal

# !ls

# !pip install -r requirements.txt torch_geometric torch torchvision torchaudio
# Out:
# Cloning into 'EGSteal'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'EGSteal'
# /content/EGSteal
# data_preparation.py		run_experiments.py
# dataset				sample_query_dataset.py
# generate_experiment_setting.py	splitters.py
# LICENSE				target_model_inference.py
# loader.py			target_model_inference_w_pretrain.py
# model.py			train_surrogate_model_for_target_w_pretrain.py
# model_w_pretrain.py		train_surrogate_model.py
# pipeline.png			train_target_model.py
# README.md			train_target_model_w_pretrain.py
# requirements.txt		utils.py
# ...

# %%
import os
os.makedirs("dataset/NCI1/raw", exist_ok=True)
os.makedirs("dataset/NCI1/processed_splits", exist_ok=True)

# %%
from torch_geometric.datasets import TUDataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-52961935.py in <cell line: 0>()
# ----> 1 from torch_geometric.datasets import TUDataset
#
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py in <module>
#      11 import torch_geometric.loader
#      12 import torch_geometric.transforms
# ---> 13 import torch_geometric.datasets
#      14 import torch_geometric.nn
#      15 import torch_geometric.explain
#
# /usr/local/lib/python3.12/dist-packages/torch_geometric/datasets/__init__.py in <module>
#      99 from .sbm_dataset import RandomPartitionGraphDataset
#     100 from .mixhop_synthetic_dataset import MixHopSyntheticDataset
# --> 101 from .explainer_dataset import ExplainerDataset
#     102 from .infection_dataset import InfectionDataset
#     103 from .ba2motif_dataset import BA2MotifDataset
#
# ...

# %%
# !pip install fsspec==2023.9.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2023.9.2 which is incompatible.
# ...

# %%
dataset = TUDataset(root='dataset', name='NCI1')
print(f"Dataset '{dataset.name}' successfully prepared with {len(dataset)} graphs.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-919890437.py in <cell line: 0>()
# ----> 1 dataset = TUDataset(root='dataset', name='NCI1')
#       2 print(f"Dataset '{dataset.name}' successfully prepared with {len(dataset)} graphs.")
#
# NameError: name 'TUDataset' is not defined

# %%
# !sed -i 's/--node_topk_percent 0.5//g' run_experiments.py
# Out:
# sed: can't read run_experiments.py: No such file or directory

# %%
# !python run_experiments.py --dataset_name NCI1 --gnn_backbone GIN --gnn_layer 3 --gnn_hidden_dim 128 --epochs 200
# Out:
# python3: can't open file '/content/run_experiments.py': [Errno 2] No such file or directory

# %%
# !ls results/
# !cat results/*.json || echo "No JSON result generated yet"
# Out:
# ls: cannot access 'results/': No such file or directory
# cat: 'results/*.json': No such file or directory
# No JSON result generated yet
